# %% [markdown]
# # Prediction using Decision Tree Algorithm

# %%
#loading of dataset
import pandas as pd
dataset=pd.read_excel("E:\Iris.xls")
print(dataset)
Data=dataset.head()
print(Data)
# Out:
#      sepal length  sepal width  petal length  petal width            iris
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# ...

# %%
#extracting data and putting them into dependent an independent variables
x=Data[['sepal length','sepal width','petal length','petal width']].values
y=Data['iris'].values
print("X=",x)
print("Y=",y)
# Out:
# X= [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# Y= ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa']

# %%
#splitting of data into training set and test set 
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)
print("xtrain=",xtrain)
print("ytrain=",ytrain)
print("xtest=",xtest)
print("ytest=",ytest)
# Out:
# xtrain= [[5.  3.6 1.4 0.2]
#  [5.1 3.5 1.4 0.2]
#  [4.6 3.1 1.5 0.2]]
# ytrain= ['Iris-setosa' 'Iris-setosa' 'Iris-setosa']
# xtest= [[4.7 3.2 1.3 0.2]
#  [4.9 3.  1.4 0.2]]
# ytest= ['Iris-setosa' 'Iris-setosa']

# %%
#loading decision tree classifier
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
model=classifier.fit(xtrain, ytrain)
print(model)
# Out:
# DecisionTreeClassifier()

# %%
#model prediction with its score
pred=model.predict(xtest)
print("predicted values=",pred)
print("Score is: ",model.score(xtest,ytest))
# Out:
# predicted values= ['Iris-setosa' 'Iris-setosa']
# Score is:  1.0

# %%
#visualising decision tree on given dataset (iris dataset)
import matplotlib.pyplot as plt
from sklearn import tree
X=dataset[['sepal length','sepal width','petal length','petal width']]
Y=dataset['iris']
model0=classifier.fit(X,Y)
plt.figure(figsize=(10,15))
tree.plot_tree(model0,filled=True)
# Out:
# [Text(279.0, 747.4499999999999, 'X[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(236.07692307692307, 611.55, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(321.9230769230769, 611.55, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(171.69230769230768, 475.65, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(85.84615384615384, 339.74999999999994, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(42.92307692307692, 203.8499999999999, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(128.76923076923077, 203.8499999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(257.53846153846155, 339.74999999999994, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(214.61538461538458, 203.8499999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %% [markdown]
# Now if any value will be entered, it will predict the right class accordingly.
# Thankyou!
